# %%
list=[10,20,50,30,10.2]
print(list[0])
# Out:
# 10

# %%
list=[10,20,30,40]
list.append(50)
print(list)
# Out:
# [10, 20, 30, 40, 50]

# %%
tuple=(1,2,3,4,5)
print(tuple[2])
# Out:
# 3

# %%
set={10,20,30,20}
print(set)
# Out:
# {10, 20, 30}

# %%
dict={"name":"hamna","age":22,"mark":50}
print(dict['name'])
# Out:
# hamna

# %%
str="shada"
print(str[0],str[4])
# Out:
# s a
